# %%
import pandas as pd
from glob import glob

# %%
# %run reusable_func.ipynb

# %%
spar_dir = "SQL_Data/Spar"
file_paths = glob(f"{spar_dir}/*.xlsx")

for file_path in file_paths:
    print(file_path)
# Out:
# SQL_Data/Spar/Copy of Insights Report_Ice Tea_Feb'24 (003).xlsx
# SQL_Data/Spar/Copy of Insights Report_Ice Tea_Mar'24.xlsx
# SQL_Data/Spar/Copy of Insights Report_Ice Tea_Apr'24.xlsx

# %%
# Read Spar Data:
# spar_path = "SQL_Data/Spar/Copy of Insights Report_Ice Tea_Mar'24.xlsx"#"SQL_Data/Spar/*.xlsx"
# spar_df = read_excel_file(spark, spar_path, sheet_name=None, sheet_index=0)
# spar_df = rename_columns(spar_df)

# %%
# Read Spar Data:
spar_all_df = read_all_excel_files(spar_dir, sheet_index=0)
spar_all_df = rename_columns(spar_all_df)
spar_all_df.show()

# %%
# Path to your Excel file
excel_path = "SQL_Data/Spar/Copy of Insights Report_Ice Tea_Apr'24.xlsx"

# Specify the sheet index (0-based)
sheet_index = 0  # Assuming the sheet you want is the first one

# Read the data from the specified sheet
df = pd.read_excel(excel_path, sheet_name=sheet_index)

# Now you can work with the DataFrame 'df'
df.head()
# Out:
#               Month-Yr Region Cluster       Barcode  \
# 0  2024-04-01 00:00:00     NR     CL2  7.371861e+11
# 1  2024-04-01 00:00:00     NR     CL2  7.371861e+11
# 2  2024-04-01 00:00:00     NR     CL2  6.001651e+12
# 3  2024-04-01 00:00:00     NR     CL2  6.001651e+12
# 4  2024-04-01 00:00:00     NR     CL2  6.001651e+12
#
#                      Product - Size   Segment  Brand                Store  \
# 0  MOYA KOMBUCHA PINEAPPLE - 500MLT  ICED TEA  OTHER            SAFI SPAR
# 1    MOYA KOMBUCHA PINEAPPLE - 1LTR  ICED TEA  OTHER            SAFI SPAR
# 2        EJ S KOMBUCHA RAW - 500MLT  ICED TEA  OTHER  BARCLAY SQUARE SPAR
# 3      EJ S KOMBUCHA SPICY - 500MLT  ICED TEA  OTHER  BARCLAY SQUARE SPAR
# 4      EJ S KOMBUCHA BUCHU - 500MLT  ICED TEA  OTHER  BARCLAY SQUARE SPAR
#
#   Format  Sales (R)\n2024  Sales (R)\n2023  Units\n2024  Units\n2023  \
# 0   SPAR           293.79           391.72         21.0         28.0
# ...

# %%
# spark_df = spark.createDataFrame(df)
# spark_df = rename_columns(spark_df)
# spark_df.show()

# %%
print(spar_all_df.count())
# Out:
# [Stage 4:======================================>                  (16 + 8) / 24]
# 66620

# %%
from glob import glob
# from functools import reduce
# from pyspark.sql.functions import lit

def read_excel_files_count(spark, directory_path, sheet_name=None, sheet_index=0):
  """
  Reads all Excel files in a directory using PySpark.

  Args:
      spark (SparkSession): The SparkSession object.
      directory_path (str): The path to the directory containing Excel files.
      sheet_name (str, optional): The name of the sheet to read (default: None).
      sheet_index (int, optional): The zero-based index of the sheet to read (default: 0).

  Returns:
      list: A list of DataFrames, each corresponding to a single Excel file.
  """


  # Get all file paths in the directory
  file_paths = glob(f"{directory_path}/*.xlsx")  # Assuming .xlsx extension

  # Read each file using the original function and append to a list
  df = None
  for file_path in file_paths:
    df = read_excel_file(spark, file_path, sheet_name, sheet_index)
    print(df.count())
  #   if df is None:
  #     df = df_temp
  #   else:
  #     df = df.union(df_temp)

  #return dfs

# %%
from pyspark.sql.types import StructType, StructField

# Get the Spark dataframe schema
schema = spar_all_df.schema

# Convert the Spark schema to a Python structfield schema
spar_schema = StructType([StructField(field.name, field.dataType, field.nullable) for field in schema.fields])

# Print the Python structfield schema
print(spar_schema)
# Out:
# StructType([StructField('Month_Yr', TimestampType(), True), StructField('Region', StringType(), True), StructField('Cluster', StringType(), True), StructField('Barcode', StringType(), True), StructField('Product___Size', StringType(), True), StructField('Segment', StringType(), True), StructField('Brand', StringType(), True), StructField('Store', StringType(), True), StructField('Format', StringType(), True), StructField('Sales_(R)_2024', DoubleType(), True), StructField('Sales_(R)_2023', DoubleType(), True), StructField('Units_2024', DoubleType(), True), StructField('Units_2023', DoubleType(), True), StructField('Sales_Gwth', DoubleType(), True), StructField('Units_Gwth', DoubleType(), True), StructField('file_path', StringType(), False)])

# %% [markdown]
# To connect to a azure database need the connect:
# `pip install com.microsoft.azure:spark-mssql-connector`
# or
# `conda install -c microsoft com.microsoft.azure:spark-mssql-connector`
# and `pip install pyspark pyodbc`

# %%
spark.stop()

# %%
#Imports
#from pyspark import SparkConf
from pyspark.sql import SparkSession

# %%
# Create a Spark session


spark = SparkSession.builder \
    .appName("WriteToSQLServer") \
    .config("spark.executor.memory", "6g") \
    .config("spark.driver.memory", "6g") \
    .config("spark.executor.cores", "4") \
    .config("spark.executor.extraJavaOptions", "-XX:+UseG1GC") \
    .config("spark.driver.extraJavaOptions", "-XX:+UseG1GC") \
    .config("spark.jars.packages", "com.microsoft.azure:spark-mssql-connector_2.12:1.1.0")\
    .getOrCreate() # .config("spark.sql.shuffle.partitions", "100") \

# """
# The parallel collector will throw an OutOfMemoryError if too much time is being spent in garbage collection: 
# if more than 98% of the total time is spent in garbage collection and less than 2% of the heap is recovered, 
# an OutOfMemoryError will be thrown. This feature is designed to prevent applications from running for an extended 
# period of time while making little or no progress because the heap is too small.
# If necessary, this feature can be disabled by adding the option -XX:-UseGCOverheadLimit to the command line.
# """

# %%
server_name = "jdbc:sqlserver://retailers.database.windows.net"
database_name = "consulting_db"
url = server_name + ";" + "databaseName=" + database_name + ";"

table_name = "staging.retailer_test"
username = "Bos"
password = "B@sNat0sh123!"

try:
  spar_all_df.write \
    .format("com.microsoft.sqlserver.jdbc.spark") \
    .mode("overwrite") \
    .option("url", url) \
    .option("dbtable", table_name) \
    .option("user", username) \
    .option("password", password) \
    .save()
except ValueError as error :
    print("Connector write failed", error)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[13], line 17
#       7 password = "B@sNat0sh123!"
#       9 try:
#      10   spar_all_df.write \
#      11     .format("com.microsoft.sqlserver.jdbc.spark") \
#      12     .mode("overwrite") \
#      13     .option("url", url) \
#      14     .option("dbtable", table_name) \
#      15     .option("user", username) \
#      16     .option("password", password) \
# ---> 17     .save()
#      18 except ValueError as error :
#      19     print("Connector write failed", error)
#
# File ~/Downloads/Scraping Shoping websites/venv/lib/python3.10/site-packages/pyspark/sql/readwriter.py:1461, in DataFrameWriter.save(self, path, format, mode, partitionBy, **options)
#    1459     self.format(format)
#    1460 if path is None:
# -> 1461     self._jwrite.save()
#    1462 else:
#    1463     self._jwrite.save(path)
#
# ...

# %%
from pyspark.sql import SparkSession

# Define the path to the JDBC driver JAR file
jdbc_driver_path = "Dependencies/sqljdbc_12.6 2/enu/jars/mssql-jdbc-12.6.2.jre8.jar"  # Change this to your actual path

# Initialize Spark session with JDBC driver
spark = SparkSession.builder \
    .appName("Azure SQL Database Interaction") \
    .config("drivers", "com.microsoft.sqlserver.jdbc.SQLServerDriver")\
    .getOrCreate()     #.config("spark.jars", jdbc_driver_path) \

# Replace placeholders with your actual details
sql_engine_name = "retailers"
server_name = "retailers.database.windows.net"
database_name = "consulting_db"
jdbc_url = f"jdbc:sqlserver://{server_name}:1433;database={database_name}"

jdbc_user = "Bos"
jdbc_password = "B@sNat0sh123!"
table_name = "staging.retailer_test"

# Configure connection properties
connection_properties = {
    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver",
    "user": jdbc_user,
    "password": jdbc_password,
    "encrypt": "true",
    "trustServerCertificate": "false",
    "hostNameInCertificate": "*.database.windows.net"
}

# Example DataFrame (you should replace this with your actual DataFrame)
data = [("John Doe", 30), ("Jane Doe", 25)]
columns = ["Name", "Age"]
spar_all_df = spark.createDataFrame(data, columns)

# Write data to Azure SQL Database
spar_all_df.write.jdbc(url=jdbc_url, table=table_name, mode="overwrite", properties=connection_properties)

# Stop the Spark session
spark.stop()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[44], line 38
#      35 spar_all_df = spark.createDataFrame(data, columns)
#      37 # Write data to Azure SQL Database
# ---> 38 spar_all_df.write.jdbc(url=jdbc_url, table=table_name, mode="overwrite", properties=connection_properties)
#      40 # Stop the Spark session
#      41 spark.stop()
#
# File ~/Downloads/Scraping Shoping websites/venv/lib/python3.10/site-packages/pyspark/sql/readwriter.py:1984, in DataFrameWriter.jdbc(self, url, table, mode, properties)
#    1982 for k in properties:
#    1983     jprop.setProperty(k, properties[k])
# -> 1984 self.mode(mode)._jwrite.jdbc(url, table, jprop)
#
# File ~/Downloads/Scraping Shoping websites/venv/lib/python3.10/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
# ...

# %%
server = "retailers.database.windows.net"
database_name = "consulting_db"
username = "Bos"
password = "B@sNat0sh123!"
driver = "{ODBC Driver 17 for SQL Server}"
connection_string = f"mssql+pyodbc://{username}:{password}@{server}/{database_name}?driver={driver}"

# %%
#Read:
spark = SparkSession.builder \
    .appName("LoadDataToAzureSQL") \
    .config("spark.executor.memory", "6g") \
    .config("spark.driver.memory", "6g") \
    .config("spark.executor.cores", "4") \
    .config("spark.executor.extraJavaOptions", "-XX:+UseG1GC") \
    .config("spark.driver.extraJavaOptions", "-XX:+UseG1GC") \
    .config("spark.jars.packages", "com.crealytics:spark-excel_2.12:0.13.7")\
    .config("spark.driver.extraClassPath","Dependencies/sqljdbc_12.6 2/enu/jars/mssql-jdbc-12.6.2.jre8.jar")\
    .getOrCreate() # .config("spark.sql.shuffle.partitions", "100") \

df = spark.read.format("jdbc") \
    .option("url", connection_string) \
    .option("dbtable", "staging.Test") \
    .option("user", username) \
    .option("password", password) \
    .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
    .load()

df.show(5)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[27], line 8
#       1 #Read:
#       2 df = spark.read.format("jdbc") \
#       3     .option("url", connection_string) \
#       4     .option("dbtable", "staging.Test") \
#       5     .option("user", username) \
#       6     .option("password", password) \
#       7     .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
# ----> 8     .load()
#      10 df.show(5)
#
# File ~/Downloads/Scraping Shoping websites/venv/lib/python3.10/site-packages/pyspark/sql/readwriter.py:314, in DataFrameReader.load(self, path, format, schema, **options)
#     312     return self._df(self._jreader.load(self._spark._sc._jvm.PythonUtils.toSeq(path)))
#     313 else:
# --> 314     return self._df(self._jreader.load())
#
# ...

# %%
#write:
df.write.format("jdbc") \
    .option("url", connection_string) \
    .option("dbtable", "staging.retailer_spar") \
    .option("user", username) \
    .option("password", password) \
    .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
    .mode("overwrite") \
    .save()

# %%
import os
os.environ['CLASSPATH'] = "Dependencies/sqljdbc_12.6 2/enu/jars/mssql-jdbc-12.6.2.jre8.jar"
#.config("spark.driver.extraClassPath","Dependencies/sqljdbc_12.6 2/enu/jars/mssql-jdbc-12.6.2.jre8.jar")\

# %%
# Replace placeholders with your actual details
sql_engine_name = "retailers"
server_name = "retailers.database.windows.net"
database_name = "consulting_db"
jdbc_url = f"jdbc:sqlserver://{server_name}:1433;database={database_name}"
jdbc_user = "Bos"
jdbc_password = "B@sNat0sh123!"
table_name = "staging.retailer_spar"

# Configure connection properties
connection_properties = {
    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver",
    "user": jdbc_user,
    "password": jdbc_password,
    "encrypt": "true",
    "trustServerCertificate": "false",
    "hostNameInCertificate": "*.database.windows.net"
}

#Write to sql:

# Write data to Azure SQL Database
spar_all_df.write.jdbc(url=jdbc_url, table=table_name, mode="overwrite", properties=connection_properties)

# Stop the Spark session
spark.stop()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[29], line 23
#      11 connection_properties = {
#      12     "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver",
#      13     "user": jdbc_user,
#    (...)
#      17     "hostNameInCertificate": "*.database.windows.net"
#      18 }
#      20 #Write to sql:
#      21
#      22 # Write data to Azure SQL Database
# ---> 23 spar_all_df.write.jdbc(url=jdbc_url, table=table_name, mode="overwrite", properties=connection_properties)
#      25 # Stop the Spark session
#      26 spark.stop()
#
# File ~/Downloads/Scraping Shoping websites/venv/lib/python3.10/site-packages/pyspark/sql/readwriter.py:1984, in DataFrameWriter.jdbc(self, url, table, mode, properties)
#    1982 for k in properties:
#    1983     jprop.setProperty(k, properties[k])
# -> 1984 self.mode(mode)._jwrite.jdbc(url, table, jprop)
#
# ...

# %%
#All connection details
jdbc_user = "Bos" #profmlungu
jdbc_password = "B@sNat0sh123!" #Florence_Wifey
table_name = "staging.retailer_spar"
#jdbc_url = "jdbc:sqlserver://retailers.database.windows.net:1433;database=consulting_db;DatabaseEncryption=yes;Encrypt=true;TrustServerCertificate=False;HostNameInCertificate=*.database.windows.net;LoginTimeout=30;"
#jdbc_url = "jdbc:sqlserver://retailers.database.windows.net:1433;database=consulting_db;user=profmlungu@retailers;password={your_password_here};encrypt=true;trustServerCertificate=false;hostNameInCertificate=*.database.windows.net;loginTimeout=30;"
jdbc_url = f"jdbc:sqlserver://{server_name};database={database_name};user={jdbc_user}@retailers;password={jdbc_password};encrypt=true;trustServerCertificate=false;hostNameInCertificate=*.database.windows.net;loginTimeout=30;"


connection_properties = {
    "user": jdbc_user,
    "password": jdbc_password,
    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}

# %%
df = spark.read.format("com.microsoft.sqlserver.jdbc.spark") \
    .option("url", jdbc_url) \
    .option("dbtable", "staging.Test") \
    .option("user", jdbc_user) \
    .option("password", jdbc_password) \
    .option('driver', 'com.microsoft.sqlserver.jdbc.SQLServerDriver')\
    .load()
df.show(5)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[18], line 7
#       1 df = spark.read.format("com.microsoft.sqlserver.jdbc.spark") \
#       2     .option("url", jdbc_url) \
#       3     .option("dbtable", "staging.Test") \
#       4     .option("user", jdbc_user) \
#       5     .option("password", jdbc_password) \
#       6     .option('driver', 'com.microsoft.sqlserver.jdbc.SQLServerDriver')\
# ----> 7     .load()
#       8 df.show(5)
#
# File ~/Downloads/Scraping Shoping websites/venv/lib/python3.10/site-packages/pyspark/sql/readwriter.py:314, in DataFrameReader.load(self, path, format, schema, **options)
#     312     return self._df(self._jreader.load(self._spark._sc._jvm.PythonUtils.toSeq(path)))
#     313 else:
# --> 314     return self._df(self._jreader.load())
#
# ...

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("AzureSQLReadWrite") \
  .config("spark.jars.packages", "com.microsoft.sqlserver:mssql-jdbc:7.2.2.jre8") \
  .getOrCreate()

# %%
df = spark.read.jdbc(url=jdbc_url, table="staging.Test", properties=connection_properties)

# Example: Print the first 5 rows
df.show(5)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df = spark.read.jdbc(url=jdbc_url, table="staging.Test", properties=connection_properties)
#       3 # Example: Print the first 5 rows
#       4 df.show(5)
#
# File ~/Downloads/Scraping Shoping websites/venv/lib/python3.10/site-packages/pyspark/sql/readwriter.py:946, in DataFrameReader.jdbc(self, url, table, column, lowerBound, upperBound, numPartitions, predicates, properties)
#     944     jpredicates = utils.toJArray(gateway, gateway.jvm.java.lang.String, predicates)
#     945     return self._df(self._jreader.jdbc(url, table, jpredicates, jprop))
# --> 946 return self._df(self._jreader.jdbc(url, table, jprop))
#
# File ~/Downloads/Scraping Shoping websites/venv/lib/python3.10/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
# ...

# %%
df = spark.read \
  .format("jdbc") \
  .option("url", jdbc_url) \
  .option("dbtable", "staging.Test") \
  .load()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[12], line 5
#       1 df = spark.read \
#       2   .format("jdbc") \
#       3   .option("url", jdbc_url) \
#       4   .option("dbtable", "staging.Test") \
# ----> 5   .load()
#
# File ~/Downloads/Scraping Shoping websites/venv/lib/python3.10/site-packages/pyspark/sql/readwriter.py:314, in DataFrameReader.load(self, path, format, schema, **options)
#     312     return self._df(self._jreader.load(self._spark._sc._jvm.PythonUtils.toSeq(path)))
#     313 else:
# --> 314     return self._df(self._jreader.load())
#
# File ~/Downloads/Scraping Shoping websites/venv/lib/python3.10/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# ...

# %%
# Write the data to Azure SQL Database
spar_all_df.write.jdbc(url=jdbc_url, table=table_name, mode="overwrite", properties=connection_properties)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Write the data to Azure SQL Database
# ----> 2 spar_all_df.write.jdbc(url=jdbc_url, table=table_name, mode="overwrite", properties=connection_properties)
#
# File ~/Downloads/Scraping Shoping websites/venv/lib/python3.10/site-packages/pyspark/sql/readwriter.py:1984, in DataFrameWriter.jdbc(self, url, table, mode, properties)
#    1982 for k in properties:
#    1983     jprop.setProperty(k, properties[k])
# -> 1984 self.mode(mode)._jwrite.jdbc(url, table, jprop)
#
# File ~/Downloads/Scraping Shoping websites/venv/lib/python3.10/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# ...

# %%
# Write DataFrame to SQL Database table
df.write \
  .format("jdbc") \
  .option("url", jdbc_url) \
  .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
  .option("user", jdbc_user) \
  .option("password", jdbc_password) \
  .option("dbtable", "your_table_name") \
  .mode("append") \
  .save()

# %%
retailers = [
    "Spar"
    ,"PNP"
    ,"Checkers"
    #,"Woolworths"
]

# %%
# Read the Excel file into a Pandas DataFrame
df_pandas_spar = pd.read_excel(r"SQL_Data/Spar/Copy of Insights Report_Ice Tea_Apr'24.xlsx")
df_pandas_spar.head()
# Out:
#               Month-Yr Region Cluster       Barcode  \
# 0  2024-04-01 00:00:00     NR     CL2  7.371861e+11
# 1  2024-04-01 00:00:00     NR     CL2  7.371861e+11
# 2  2024-04-01 00:00:00     NR     CL2  6.001651e+12
# 3  2024-04-01 00:00:00     NR     CL2  6.001651e+12
# 4  2024-04-01 00:00:00     NR     CL2  6.001651e+12
#
#                      Product - Size   Segment  Brand                Store  \
# 0  MOYA KOMBUCHA PINEAPPLE - 500MLT  ICED TEA  OTHER            SAFI SPAR
# 1    MOYA KOMBUCHA PINEAPPLE - 1LTR  ICED TEA  OTHER            SAFI SPAR
# 2        EJ S KOMBUCHA RAW - 500MLT  ICED TEA  OTHER  BARCLAY SQUARE SPAR
# 3      EJ S KOMBUCHA SPICY - 500MLT  ICED TEA  OTHER  BARCLAY SQUARE SPAR
# 4      EJ S KOMBUCHA BUCHU - 500MLT  ICED TEA  OTHER  BARCLAY SQUARE SPAR
#
#   Format  Sales (R)\n2024  Sales (R)\n2023  Units\n2024  Units\n2023  \
# 0   SPAR           293.79           391.72         21.0         28.0
# ...

# %%
df_pandas_spar.tail(20)
# Out:
#                                                 Month-Yr Region Cluster  \
# 21347                                2024-04-01 00:00:00     LV     CL9
# 21348                                2024-04-01 00:00:00     LV     CL9
# 21349                                2024-04-01 00:00:00     LV     CL9
# 21350                                2024-04-01 00:00:00     LV     CL9
# 21351                                2024-04-01 00:00:00     LV     CL9
# 21352                                2024-04-01 00:00:00     LV     CL9
# 21353                                2024-04-01 00:00:00     LV     CL9
# 21354                                2024-04-01 00:00:00     LV     CL9
# 21355                                2024-04-01 00:00:00     LV     CL9
# 21356                                                NaN    NaN     NaN
# 21357                                  Selection Status:    NaN     NaN
# 21358                                  Segment: ICED TEA    NaN     NaN
# ...

# %%
# Read the Excel file into a Pandas DataFrame
df_pandas_pnp = pd.read_excel(r"SQL_Data/PNP/KPITrends_01_02_2024_29_02_2024_to_01_02_2024_29_02_2024_ZA (4).xlsx")
df_pandas_pnp.head()
# Out:
#                                             Query ID  \
# 0                                          Territory
# 1                                   Data Sample Size
# 2                                               Time
# 3                                            Product
# 4  Edible Grocery  Beverages (CSD, Coffee & Juice...
#
#                 70fd0090-d7e0-40d3-9e54-01138a3d9229
# 0                                       South Africa
# 1                                               100%
# 2  01/02/2024 - 29/02/2024 compared to 01/02/2024...
# 3                                                NaN
# 4                                                NaN

# %%
# Read the excel file
df_pnp = pd.read_excel(r"SQL_Data/PNP/KPITrends_01_02_2024_29_02_2024_to_01_02_2024_29_02_2024_ZA (4).xlsx", sheet_name='KPI Trends')

# %%
df_pnp.head()
# Out:
#    Calendar Month/Year    Site Name  Site                   Article Name  \
# 0                  NaN       Result   NaN                         Result
# 1             202402.0       Result   NaN                         Result
# 2             202402.0       Result   NaN  MANHATTAN ICE TEA PEACH 500ML
# 3             202402.0  Walmer Park  EC01  MANHATTAN ICE TEA PEACH 500ML
# 4             202402.0  Newton Park  EC03  MANHATTAN ICE TEA PEACH 500ML
#
#     Article  Customers Select. Per.  Tot. Customers Select. Per.  \
# 0       NaN                   53932                      5026415
# 1       NaN                   53932                      5026415
# 2  102503.0                     584                      5026415
# 3  102503.0                       3                      5026415
# 4  102503.0                       4                      5026415
#
#    Customers Pen. Select. Per  Sales Units Select. Per. Measure  ...  \
# ...

# %%
# Convert the Pandas DataFrame to a Spark DataFrame
df_spark = spark.createDataFrame(df_pnp)

# %%
# Print the Spark DataFrame
df_spark.printSchema()
# Out:
# root
#  |-- Calendar Month/Year: double (nullable = true)
#  |-- Site Name: string (nullable = true)
#  |-- Site: string (nullable = true)
#  |-- Article Name: string (nullable = true)
#  |-- Article: double (nullable = true)
#  |-- Customers Select. Per.: long (nullable = true)
#  |-- Tot. Customers Select. Per.: long (nullable = true)
#  |-- Customers Pen. Select. Per: double (nullable = true)
#  |-- Sales Units Select. Per.: long (nullable = true)
#  |-- Measure: string (nullable = true)
#  |-- Sales Unit Part. Select. Per: double (nullable = true)
#  |-- Net Sales Value Select. Per.: long (nullable = true)
#  |-- Measure.1: string (nullable = true)
#  |-- Net Sales Value Part. Select. Per.: double (nullable = true)
#  |-- Transaction Select. Per.: long (nullable = true)
#  |-- Transaction Pen Select Per.: double (nullable = true)
#  |-- Tot. Transaction Select. Per.: long (nullable = true)
#  |-- Avg Customer Freq. Select. Per: double (nullable = true)
# ...

# %%
from pyspark.sql.types import StructType, StructField

# Get the Spark dataframe schema
schema = df_spark.schema

# Convert the Spark schema to a Python structfield schema
python_schema = StructType([StructField(field.name, field.dataType, field.nullable) for field in schema.fields])

# Print the Python structfield schema
print(python_schema)
# Out:
# StructType([StructField('Calendar Month/Year', DoubleType(), True), StructField('Site Name', StringType(), True), StructField('Site', StringType(), True), StructField('Article Name', StringType(), True), StructField('Article', DoubleType(), True), StructField('Customers Select. Per.', LongType(), True), StructField('Tot. Customers Select. Per.', LongType(), True), StructField('Customers Pen. Select. Per', DoubleType(), True), StructField('Sales Units Select. Per.', LongType(), True), StructField('Measure', StringType(), True), StructField('Sales Unit Part. Select. Per', DoubleType(), True), StructField('Net Sales Value Select. Per.', LongType(), True), StructField('Measure.1', StringType(), True), StructField('Net Sales Value Part. Select. Per.', DoubleType(), True), StructField('Transaction Select. Per.', LongType(), True), StructField('Transaction Pen Select Per.', DoubleType(), True), StructField('Tot. Transaction Select. Per.', LongType(), True), StructField('Avg Customer Freq. S
# ...

# %%
# Read the Excel file into a Pandas DataFrame
df_pandas_ww = pd.read_excel(r"SQL_Data/Woolworths/WW BOS sales FY23-24 April.xlsx")
df_pandas_ww.head()
# Out:
#              Location                                 10 - CORPORATE  \
# 0            Supplier                   11886 - BOS BRANDS (PTY) LTD
# 1                 NaN                                            NaN
# 2               Sales                                            NaN
# 3                 NaN                                            NaN
# 4  43 - ICE TEA 330ML  6009881007706 - 300ML BOS PEACH ICED - 644333
#
#   Unnamed: 2  Unnamed: 3  Unnamed: 4         Unnamed: 5  Unnamed: 6  \
# 0        NaN         NaN         NaN                NaN         NaN
# 1        NaN         NaN         NaN                NaN         NaN
# 2        NaN         NaN         NaN                NaN         NaN
# 3     APR 24         NaN         NaN                NaN         NaN
# 4  241031.94         NaN         NaN  April Grand Total  3180329.43
#
#    Unnamed: 7  Unnamed: 8                                     Unnamed: 9  \
# ...

# %%
# Convert the Pandas DataFrame to a Spark DataFrame
df_spark = spark.createDataFrame(df_pandas)

# Print the Spark DataFrame
df_spark.show()

# %%
print(table_name)
# Out:
# your_table_name

# %%
# Write the data to Azure SQL Database
df_transformed.write.jdbc(url=jdbc_url, table=table_name, mode="overwrite", properties=connection_properties)

# %%
# Example transformation: Select specific columns
df_transformed = df.select("column1", "column2")
